# %% [markdown]
# # Forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
#ts_data = pd.read_csv('Time_Series_KPComp.csv', parse_dates=['period_dt'], index_col='period_dt',date_parser=dateparse)
ts_data = pd.read_csv('Time_Series_KPComp.csv')

ts_data.head()
# Out:
#             ﻿Measure_Name series_name   period_dt  mjr_wrk  value
# 0  C-diff per 10K Pt Days      HI-MOA  2011-06-30        0  8.834
# 1  C-diff per 10K Pt Days      HI-MOA  2011-09-30        0  6.474
# 2  C-diff per 10K Pt Days      HI-MOA  2011-12-31        0  6.385
# 3  C-diff per 10K Pt Days      HI-MOA  2012-03-31        0  6.597
# 4  C-diff per 10K Pt Days      HI-MOA  2012-06-30        0  5.810

# %%
ts_data.dtypes
# Out:
# ﻿Measure_Name     object
# series_name       object
# period_dt         object
# mjr_wrk            int64
# value            float64
# dtype: object

# %%
# convert to date-time
#ts_data['period_t'] =ts_data.period_dt.apply(pd.to_datetime)
#ts_data.dtypes

# %%
#dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
ts_data.head()
# Out:
#             ﻿Measure_Name series_name   period_dt  mjr_wrk  value
# 0  C-diff per 10K Pt Days      HI-MOA  2011-06-30        0  8.834
# 1  C-diff per 10K Pt Days      HI-MOA  2011-09-30        0  6.474
# 2  C-diff per 10K Pt Days      HI-MOA  2011-12-31        0  6.385
# 3  C-diff per 10K Pt Days      HI-MOA  2012-03-31        0  6.597
# 4  C-diff per 10K Pt Days      HI-MOA  2012-06-30        0  5.810

# %%
ts_data["year"] = ts_data.period_dt.apply(lambda x : x.split("-")[0])
ts_data["day"] = ts_data.period_dt.apply(lambda x : x.split("-")[1])
import calendar
import datetime
ts_data["weekday"] = ts_data.period_dt.apply(lambda x : calendar.day_name[datetime.datetime.strptime(x,"%Y-%m-%d").weekday()])
ts_data["month"] = ts_data.period_dt.apply(lambda x : calendar.month_name[datetime.datetime.strptime(x,"%Y-%m-%d").month])
#ts_data["year"] = ts_data.period_dt.apply(lambda x : calendar.month_name[datetime.datetime.strptime(x,"%Y-%m-%d").month])
ts_data.head()
# Out:
#             ﻿Measure_Name series_name   period_dt  mjr_wrk  value  year day  \
# 0  C-diff per 10K Pt Days      HI-MOA  2011-06-30        0  8.834  2011  06
# 1  C-diff per 10K Pt Days      HI-MOA  2011-09-30        0  6.474  2011  09
# 2  C-diff per 10K Pt Days      HI-MOA  2011-12-31        0  6.385  2011  12
# 3  C-diff per 10K Pt Days      HI-MOA  2012-03-31        0  6.597  2012  03
# 4  C-diff per 10K Pt Days      HI-MOA  2012-06-30        0  5.810  2012  06
#
#     weekday      month
# 0  Thursday       June
# 1    Friday  September
# 2  Saturday   December
# 3  Saturday      March
# 4  Saturday       June

# %%
# Make it an index

# %%
AO = ts_data ["value"]
AO.plot()
plt.show()

# %%
ts_data.set_index('period_dt')
# Out:
#                                    ﻿Measure_Name series_name  mjr_wrk  \
# period_dt
# 2011-06-30                C-diff per 10K Pt Days      HI-MOA        0
print('Data Types:')
print(ts_data.dtypes)
# Out:
# Data Types:
# ﻿Measure_Name     object
# series_name       object
# period_dt         object
# mjr_wrk            int64
# value            float64
# year              object
# day               object
# weekday           object
# month             object
# dtype: object

# %%
from statsmodels.tsa.stattools import adfuller
#def test_stationarity(timeseries):
    
    #Determing rolling statistics
 #   rolmean = pd.rolling_mean(timeseries, window=12)
 #   rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
 #   orig = plt.plot(timeseries, color='blue',label='Original')
 #   mean = plt.plot(rolmean, color='red', label='Rolling Mean')
 #   std = plt.plot(rolstd, color='black', label = 'Rolling Std')
 #   plt.legend(loc='best')
 #   plt.title('Rolling Mean & Standard Deviation')
 #   plt.show(block=False)
    
    #Perform Dickey-Fuller test:
 #   print('Results of Dickey-Fuller Test:')
 #   dftest = adfuller(timeseries, autolag='AIC')
 #   dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
 #   for key,value in dftest[4].items():
 #       dfoutput['Critical Value (%s)'%key] = value
 #   print(dfoutput)
    
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    
C_Diff_ts = ts_data.value[(ts_data.Measure_Name == 'C-diff per 10K Pt Days') & (ts_data.series_name == 'KP-Nat')]

test_stationarity(C_Diff_ts)



# Let's perform some differencing to eliminate trend/seasonality

C_Diff_ts_diff = C_Diff_ts - C_Diff_ts.shift()
plt.plot(C_Diff_ts_diff)

#Compare this
C_Diff_ts_diff.dropna(inplace = True)
test_stationarity(C_Diff_ts_diff)

#ARIMA Model
from statsmodels.tsa.arima_model import ARIMA
arima_model = ARIMA(C_Diff_ts, order = (2,1,2))
ARIMA_results = arima_model.fit(disp = -1)
plt.plot(C_Diff_ts_diff)
plt.plot(ARIMA_results.fittedvalues, color = 'green')
plt.title('RSS: %.4f'% sum((ARIMA_results.fittedvalues-C_Diff_ts_diff)**2))

predictions_ARIMA_diff = pd.Series(ARIMA_results.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())

predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())

#Change back to originals
predictions_ARIMA = pd.Series(C_Diff_ts.ix[0], index = C_Diff_ts.index)
predictions_ARIMA = predictions_ARIMA.add(predictions_ARIMA_diff_cumsum, fill_value = 0)
predictions_ARIMA.head()

plt.plot(C_Diff_ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-C_Diff_ts)**2)/len(C_Diff_ts)))
# Out:
#                      ﻿Measure_Name series_name  mjr_wrk  value
# period_dt
# 2011-06-30  C-diff per 10K Pt Days      HI-MOA        0  8.834
# 2011-09-30  C-diff per 10K Pt Days      HI-MOA        0  6.474
# 2011-12-31  C-diff per 10K Pt Days      HI-MOA        0  6.385
# 2012-03-31  C-diff per 10K Pt Days      HI-MOA        0  6.597
# 2012-06-30  C-diff per 10K Pt Days      HI-MOA        0  5.810
#
#  Data Types:
# ﻿Measure_Name     object
# series_name       object
# mjr_wrk            int64
# value            float64
# dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e810c816881e> in <module>()
#      59
#      60
# ---> 61 C_Diff_ts = ts_data.value[(ts_data.Measure_Name == 'C-diff per 10K Pt Days') & (ts_data.series_name == 'KP-Nat')]
#      62
#      63 test_stationarity(C_Diff_ts)
#
# /Users/taposh/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Measure_Name'
